# %% [markdown]
# <a href="https://colab.research.google.com/github/mrsyamhfis/Python_Pandas/blob/main/Plotting_Systems_in_Python_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# pyplot is matplotlib's internal library which halps create data visualisation easily

# %%
#initializing the data
x = [10, 20, 30, 40]
y = [20, 30, 40, 50]

# %%
#plotting the data
plt.plot(x, y)

#adding the title
plt.title("simple plot")

#adding the labels
plt.ylabel("y-axis")
plt.xlabel("x-axis")

#to render/create plot as an output
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

#setting limits for axis[x1,x2,y1,y2]
plt.axis([0,6,0,20])

plt.show()

# %% [markdown]
# A figure can have multiple axes. Meaning a figure is like a canvas, so a canvas can have multiple graphs.

# %%
from matplotlib.figure import Figure

# %%
#creating a new figure with width = 5 inches
#and  height = 4 inches
fig = plt.figure(figsize =(5, 4))

#creating the axes object with argument as 
#[left, bottom, width, height]
#creating a new axes for the figure
ax = fig.add_axes([1, 1, 1, 1])

#adding the data to be plotted
ax.plot([2,3,4,5,5,6,6],
        [5,7,1,3,4,6,8])
plt.show()

# %% [markdown]
# ## Axes class
#
# Axes class is the most basic and flexible unit for creating sub-plots. A given figure may contain many axes, but a given axes can only be present on one figure. The *axes()* function creates the axes object.

# %%
# reinstating the python program to show pyplot module under axes class
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %%
# creating only the axes object with argument as [left, bottom, width, height]
ax = plt.axes([1, 1, 1, 1])

# %%
# creating a figure
fig = plt.figure(figsize = (5, 4))

# adding the axes to the figure
ax = fig.add_axes([1, 1, 1, 1])

# plotting 2 kinds of datasets
# 1st dataset
ax1 = ax.plot([1, 2, 3, 4], [1, 2, 3, 4])

# 2nd dataset
ax2 = ax.plot([1, 2, 3, 4], [2, 3, 4, 5])

# 3rd dataset
ax3 = ax.plot([1, 2, 3, 4], [3, 4, 5, 6])

# %% [markdown]
# ## Setting limits and tick labels
#
# - You might have seen that Matplotlib automatically sets the values and the markers (points) of the x and y axis.
# - However, it is possible to set the limit and markers manually.
# - set_xlimit() and set_ylimit() functions are used to set the limits of the x-axis and y-axis respectively.
# - Similarly, set_xticklabels() and set_yticklabels() functions are used to set tick labels.

# %%
# python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
x = [3, 1, 3]
y = [3, 2, 1]

# creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# creating first axes for the figure
# creating the axes object with argument as
# [left, bottom, width, height]
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# adding the data to be plotted
ax.plot(x, y)
ax.set_xlim((1, 6))
ax.set_ylim((1, 4))
ax.set_xticklabels(("one", "two", "three", "four", "five", "six"))
plt.show()
# Out:
# <ipython-input-28-40acc49cf27d>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(("one", "two", "three", "four", "five", "six"))

# %% [markdown]
# Adding annotations and arrows

# %%
import numpy as np

ax = plt.axes()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4), 
            arrowprops=dict(facecolor= 'blue', shrink=0.05))

ax.annotate('local minimum', xy=(5*np.pi, -1), xytext=(2, -4), 
            arrowprops=dict(arrowstyle='wedge,tail_width=0.4', alpha=1.0, facecolor='blue'), bbox=dict(boxstyle='round', alpha=0.5));

#alpha is for colour transparency

# %% [markdown]
# # Multiple Plots
#
# - Plotting multiple plots in the same figure.
# - There are two ways
#
#
# ### **Method 1: Using add_axes() method**
#
# **Syntax:**
#
# *add_axes(self,args,kwargs)*
#
# used to add axes in figure

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# Creating a new figure with width - 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))

# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])

#Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])

# Adding the data to be plotted
ax1.plot([5, 4, 3, 2, 1], [2, 3, 4, 5, 6])
ax2.plot([1, 2, 3, 4, 5], [2, 3, 4, 5, 6])
plt.show()

# %% [markdown]
# ## **Method 2: Using subplot() method**
#
# This method adds another plot to the current figure at the specified grid position.
#
# **Syntax:**
#
# *subplot(nrows, ncols, index, kwargs)*
#
# *subplot(pos, kwargs)*
#
# *subplot(ax)*
#
# used to add axes in figure

# %%
import matplotlib.pyplot as plt
# data to display on plots
x = [3, 1, 3]
y = [3, 2, 1]
z = [1, 3, 1]
w = [1, 3, 1]

# creating figure object
plt.figure(figsize = (10,5))

#adding first subplot
plt.subplot(121) # 1 - row, 3 - columns, 1 - plot number 1
plt.plot(x, y)

#adding second subplot
plt.subplot(132) # 1 - row, 3 - columns, 2 - plot number 2
plt.plot(z, y)

#adding third subplot
plt.subplot(133) # 1 - row, 3 - columns, 3 - plot number 3
plt.plot(z, w)
# Out:
# <ipython-input-2-b05706c8f853>:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(132) # 1 - row, 3 - columns, 2 - plot number 2

# %% [markdown]
# # **Method 3: Using subplots() method**
#
# This function is used to create figure and multiple subplots at the same time.
#
# Syntax:
#
# matplotlib.pyplot.subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)

# %%
import matplotlib.pyplot as plt

#creating the figure and subplots
#according the argument passed
fig, axes = plt.subplots(2, 2)

#plotting the data in the 1st subplot
axes[0][0].plot([1, 2, 3, 4], [1, 2, 3, 4])

#plotting the data in the 2nd subplot
axes[0][0].plot([1, 2, 3, 4], [4, 3, 2, 1])

#plotting the data in the 1st subplot
axes[1][1].plot([1, 2, 3, 4], [1, 1, 1, 1])

# %% [markdown]
# ## **Legend**

# %%
import matplotlib.pyplot as plt

#data to display on plots
x = [3, 1, 3]
y = [3, 2, 1]
plt.plot(x, y, c = "blue")
plt.plot(y, x,  c = "orange")

#adding the legends
plt.legend(['blue', 'orange'], loc = 'lower left')
plt.show()
